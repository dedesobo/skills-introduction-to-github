# %% [markdown]
# <a href="https://colab.research.google.com/github/dedesobo/skills-introduction-to-github/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("bonjour python")
# Out:
# bonjour python
